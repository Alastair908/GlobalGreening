# %%
import pandas as np
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Getting the images for the presentation

# %%
esa_mask = np.load('../raw_data/ESA_worldcover/land_use_data_from_0_to_249.npy')
plt.imshow(esa_mask[0])
